# %%
def strin(string):
    count=0
    alpha="aeiouAEIOU"
    for i in string:
        if i in alpha:
            count+=1
        return count

# %%
strin("akakaa")
# Out:
# 1

# %%
print("hello","world",sep=" ")
# Out:
# hello world

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
with open("lala.txt",mode="a+") as file:
    file.write("nweee")
    print(file.read())

# %%
lis=[]
def inp():
    for i in range(5):
        inpu=int(input("enter number"))
        lis.append(inpu)
    return lis

# %%
inp()
# Out:
# enter number 1
# enter number 2
# enter number 3
# enter number 4
# enter number 5
# [1, 2, 3, 4, 5]

# %%
with open("add.txt",mode="w+") as file:
    file.write(str(inp()))
    print(file.read())
# Out:
# enter number 1
# enter number 1
# enter number 1
# enter number 1
# enter number 1

# %%
lala=[1,2,3,4,5]
for i,v in enumerate(lala,start=0):
    print(i,v)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %%
names=["abi","khadka","lalala"]
for i,names in enumerate(names,start=1):
    print(f"{names} with roll no:{i}")
# Out:
# abi with roll no:1
# khadka with roll no:2
# lalala with roll no:3

# %%
dic={"name":"abi","gender":"male","age":191}
for i,(k,v) in enumerate(dic.items()):
    print(k,v)
# Out:
# name abi
# gender male
# age 191

# %%
dic.items()
# Out:
# dict_items([('name', 'abi'), ('gender', 'male'), ('age', 191)])

# %%
lst=["name","gender","dob"]
lst1=["lala","kaka",19191]
lst2=[1,2,3]
lst3=["sa","asa","ss"]
lst4=["asxa","asas","dsa"]
la=list(zip(lst,lst1,lst2,lst3,lst4))
print((la))
# Out:
# [('name', 'lala', 1, 'sa', 'asxa'), ('gender', 'kaka', 2, 'asa', 'asas'), ('dob', 19191, 3, 'ss', 'dsa')]

# %%
for a,b,c,d,e in la:
    print(a,b,c,d)
# Out:
# name lala 1 sa
# gender kaka 2 asa
# dob 19191 3 ss

# %%
lala=[1,2,3,4,5]
lalala=[x*x for x in lala ]
print(lalala)
# Out:
# [1, 4, 9, 16, 25]

# %%
def sur(x):
    return x*x
o=[1,2,3,4]

# %%
la=map(sur,o)

print(list(la))
# Out:
# [1, 4, 9, 16]

# %%
sisi={"name":"ss","name":"laa"}

# %%
print(sisi["name"])
# Out:
# laa

# %%
la={"a":888,"b":44}
print(max(la.values()))
print(len(la))
# Out:
# 888
# 2

# %%
print(max(la,key=la.get))
# Out:
# a
