# %%
lat=[1,2,3,4,5,6,7]
def eve(num):
    if num%2==0:
        return num
    else:
        return "null"
        
lala=list(filter(eve,lat))
print(list(map(eve,lat)))
print(lala)
# Out:
# ['null', 2, 'null', 4, 'null', 6, 'null']
# [1, 2, 3, 4, 5, 6, 7]

# %%
from functools import reduce
li=[1,2,3,4,5,9]
def cu(num,num1):
        if num>num1:
            return num
        else:
            return num1
la=print(reduce(cu,li))
# Out:
# 9

# %% [markdown]
# # single value then use reduce
# # condition value then use filter
# # check all then use map

# %%
def la(a:int,b:int) ->int:
    """
    uses two integers 
    returns:
    sum of two numbers"""
    return a+b

# %%
la.__doc__
# Out:
# '\nuses two integers \nreturns:\nsum of two numbers'

# %%
def pri(*la:str)->str:
    """THIS USES ARGUMENT"""
    return f"{la}"
print((pri("welcome","to","nepal")))
# Out:
# ('welcome', 'to', 'nepal')

# %%
def ret(**k):
    return f"{k}"

# %%
print(ret(name="ka",age=99))
# Out:
# {'name': 'ka', 'age': 99}

# %%
def data(a,*b,**c):
    print(a)
    print(b)
    print(c)

print(data(1,2,3,4,name="ola",age=88))
# Out:
# 1
# (2, 3, 4)
# {'name': 'ola', 'age': 88}
# None

# %%
def pizza(a,*b,**c):
    print(f"total number of pizza=={a}")
    for i in b:
        print(f"Types::{i}")
    print(f"NAME OF ORDER=={c}")
typee=[]
while True:
    print("you want to order pizza")
    try:
        option=input("ENTER YES OR NO ")
    except ValueError as e:
        print("error",e)
    if option.upper().startswith("Y"):
        no_of_pizza=int(input("enter the number of pizza"))
        typeee=input("enter the type of pizza")
        typee.append(typeee)
        while True:
            print("want more??")
            opt=input()
            if opt.upper().startswith("Y"):
                typeee=input("enter the type of pizza")
                typee.append(typeee)
            else:
                break
    else:
        break
# Out:
# you want to order pizza
# ENTER YES OR NO  yes
# enter the number of pizza 2
# enter the type of pizza chi
# want more??
#  yes
# enter the type of pizza buff
# want more??
#  no
# you want to order pizza
# ENTER YES OR NO  no

# %%
pizza(no_of_pizza,typee,name=input("ENTER NAME "),orderno=int(input("enter order no ")))
# Out:
# ENTER NAME  la
# enter order no  8
# total number of pizza==2
# Types::['chi', 'buff']
# NAME OF ORDER=={'name': 'la', 'orderno': 8}
